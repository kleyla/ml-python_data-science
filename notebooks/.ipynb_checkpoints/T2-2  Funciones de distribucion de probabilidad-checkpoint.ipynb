# %% [markdown]
# # Funciones de distribucion de probabilidades

# %% [markdown]
# ## Distribucion Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
b = 100
n = 1000
data = np.random.uniform(a, b, n)

# %%
# %matplotlib inline

# %%
plt.hist(data)
# Out:
# (array([ 92.,  85., 112.,  89.,  96.,  86., 101., 101., 106., 132.]),
#  array([ 1.08321613, 10.9678525 , 20.85248887, 30.73712525, 40.62176162,
#         50.50639799, 60.39103436, 70.27567073, 80.16030711, 90.04494348,
#         99.92957985]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Distribucion Normal

# %% [markdown]
# ### La campana de Gauss

# %%
data = np.random.randn(1000)

# %%
x = range(1,1001)
plt.plot(x, data)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([ 16.,  39.,  95., 152., 217., 191., 146., 102.,  31.,  11.]),
#  array([-2.81417123, -2.25222428, -1.69027732, -1.12833037, -0.56638341,
#         -0.00443646,  0.5575105 ,  1.11945745,  1.68140441,  2.24335136,
#          2.80529831]),
#  <a list of 10 Patch objects>)

# %%
# sorted ordenada caracteriza una funcion gausiana
plt.plot(x, sorted(data))

# %%
mu = 5.5
sd = 2.5
Z = np.random.randn(1000)
data = mu + sd*Z # Z= (X - mu) / sd
plt.hist(data)
# Out:
# (array([  4.,  14.,  80., 139., 245., 230., 191.,  71.,  22.,   4.]),
#  array([-2.65858534, -1.05879824,  0.54098886,  2.14077596,  3.74056306,
#          5.34035016,  6.94013726,  8.53992436, 10.13971146, 11.73949856,
#         13.33928567]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(2,4)
data
# Out:
# array([[-0.21548053,  1.35112901, -0.51869962,  1.41550819],
#        [-0.62938526, -1.26305013,  0.36322833, -0.02142035]])

# %% [markdown]
# ## La simulacion de Monte Carlo

# %% [markdown]
# * Generamos dos numeros aleatorios x e y entre 0 y 1
# * Calcularemos x * x + y * y
#      * Si el valor es inferio a 1 -> estamos dentro del circulo
#      * Si el valor es superior a 1 estamos fuera del circulo
# * Calculamos el numeri total de veces q estan dentro del circulo y lo dividimos entre el numero total de intentos para obtener una aprox de la probabilidad de caer dentro del circulo.
# * Usamos dicha probabilidad para aproximar el valor de pi
# * Repetimos el experimento un numero suficiente de veces por ejem. 1000 para obtener 1000 diferentes aprox de pi
# * Calculamos el promedio de los 1000 experimentos anteriores para dar un valor final de pi

# %%
def pi_montecarlo(n, n_exp):
    pi_avg = 0
    n = 1000
    pi_value_list = []
    for i in range(n_exp):
        value = 0
        x = np.random.uniform(0, 1, n).tolist()
        y = np.random.uniform(0, 1, n).tolist()
        for j in range(n):
            z = np.sqrt(x[j] * x[j] + y[j] *y[j]) 
            if z <= 1:
                value += 1
        float_value = float(value)
        pi_value = float_value * 4 / n
        pi_value_list.append(pi_value)
        pi_avg += pi_value
    pi = pi_avg/n_exp

    print(pi)
    fig = plt.plot(pi_value_list)
    return fig

# %%
pi_montecarlo(1000, 200)
# Out:
# 3.1402600000000005
