# %% [markdown]
# # Data wrangling - La cirugia de los datos

# %% [markdown]
# El data wrangling a veces denominada data munging es el proceso de transformar y mapear datos de un dataset raw (en bruto) en otro formato con la intencion de hacerlo mas apropiado y valioso para una variedad de propositos posteriores, como el analisis. Una data wrangler es una persona que realiza estas operaciones de transformacion.
# Esto puede incluir munging visualizacion de datos, agregacion de datos, entrenamiento de un modelo estadistico, asi como muchos otros usos potenciales. La oscilacion de datos como proceso generalmente sigue un conjunto de pasos generales que comienzan extrayendo los datos en forma cruda del origen de datos, dividiendo los datos en bruto usando algoritmos (por ejemplo clasificacion) o analizando los datos en estructuras de datos predefinidas y finalmente depositando el contenido resultante en un sistema de almacenamiento (o silo) para su futuro uso.

# %%
import pandas as pd

# %%
data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Crear un subconjunto de datos

# %%
# a veces solo necesitamos algunas columnas y no todas
account_len = data["Account Length"]

# %%
account_len.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_len)
# Out:
# pandas.core.series.Series

# %%
subset = data[["Account Length", "Phone", "Eve Charge", "Day Calls"]]

# %%
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
desired_cols = ["Account Length", "Phone", "Eve Charge", "Night Calls"]

# %%
subset = data[desired_cols]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Night Calls
# 0             128  382-4657       16.78           91
# 1             107  371-7191       16.62          103
# 2             137  358-1921       10.30          104
# 3              84  375-9999        5.26           89
# 4              75  330-6626       12.61          121

# %%
desired_cols = ["Account Length", "VMail Message", "Day Calls"]
desired_cols
# Out:
# ['Account Length', 'VMail Message', 'Day Calls']

# %%
all_cols_list = data.columns.values.tolist()
all_cols_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = [x for x in all_cols_list if x not in desired_cols]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset
# Out:
#      State  Area Code     Phone Int'l Plan VMail Plan  Day Mins  Day Charge  \
# 0       KS        415  382-4657         no        yes     265.1       45.07
# 1       OH        415  371-7191         no        yes     161.6       27.47
# 2       NJ        415  358-1921         no         no     243.4       41.38
# 3       OH        408  375-9999        yes         no     299.4       50.90
# 4       OK        415  330-6626        yes         no     166.7       28.34
# 5       AL        510  391-8027        yes         no     223.4       37.98
# 6       MA        510  355-9993         no        yes     218.2       37.09
# 7       MO        415  329-9001        yes         no     157.0       26.69
# 8       LA        408  335-4719         no         no     184.5       31.37
# 9       WV        415  330-8173        yes        yes     258.6       43.96
# 10      IN        415  329-6603         no         no     129.1       21.95
# 11      RI        415  344-9403         no         no     187.7       31.91
# 12      IA        408  363-1107         no         no     128.8       21.90
# 13      MT        510  394-8006         no         no     156.6       26.62
# 14      IA        415  366-9238         no         no     120.7       20.52
# 15      NY        415  351-7269         no         no     332.9       56.59
# 16      ID        408  350-8884         no        yes     196.4       33.39
# 17      VT        510  386-2923         no         no     190.7       32.42
# 18      VA        510  356-2992         no        yes     189.7       32.25
# 19      TX        415  373-2782         no         no     224.4       38.15
# 20      FL        415  396-5800         no         no     155.1       26.37
# 21      CO        408  393-7984         no         no      62.4       10.61
# 22      AZ        415  358-1958         no         no     183.0       31.11
# 23      SC        415  350-2565         no         no     110.4       18.77
# 24      VA        510  343-4696         no         no      81.1       13.79
# 25      NE        415  331-3698         no         no     124.3       21.13
# 26      WY        408  357-3817         no        yes     213.0       36.21
# 27      MT        408  418-6412         no         no     134.3       22.83
# 28      MO        415  353-2630         no         no     190.0       32.30
# 29      HI        510  410-7789         no         no     119.3       20.28
# ...    ...        ...       ...        ...        ...       ...         ...
# 3303    WI        415  373-7308         no        yes     137.1       23.31
# 3304    IL        510  330-7137        yes         no     186.1       31.64
# 3305    IN        415  406-8445         no        yes     224.1       38.10
# 3306    AL        408  404-5283         no        yes      83.6       14.21
# 3307    OK        408  398-3632         no         no     203.9       34.66
# 3308    IA        415  399-5763         no         no     211.3       35.92
# 3309    VT        408  340-9449        yes         no     219.4       37.30
# 3310    NY        415  363-1123         no         no     190.4       32.37
# 3311    LA        415  361-2170         no         no     147.7       25.11
# 3312    SC        408  406-6304         no         no     229.9       39.08
# 3313    ID        408  392-5090         no         no     102.8       17.48
# 3314    MO        415  373-7713         no         no     178.7       30.38
# 3315    ME        415  392-1376         no        yes     148.5       25.25
# 3316    MS        510  390-6388         no        yes     164.1       27.90
# 3317    SD        415  379-7290        yes         no     197.2       33.52
# 3318    OK        415  397-9928         no         no     124.9       21.23
# 3319    WY        415  378-6924         no         no     115.4       19.62
# 3320    GA        510  411-5677        yes         no     140.0       23.80
# 3321    VT        415  400-2738         no         no     193.9       32.96
# 3322    MD        408  409-1856         no         no     321.1       54.59
# 3323    IN        415  362-5899         no         no     118.4       20.13
# 3324    WV        415  377-1164         no         no     169.8       28.87
# 3325    OH        408  368-8555         no         no     193.4       32.88
# 3326    OH        415  347-6812         no         no     106.6       18.12
# 3327    SC        415  348-3830         no         no     134.7       22.90
# 3328    AZ        415  414-4276         no        yes     156.2       26.55
# 3329    WV        415  370-3271         no         no     231.1       39.29
# 3330    RI        510  328-8230         no         no     180.8       30.74
# 3331    CT        510  364-6381        yes         no     213.8       36.35
# 3332    TN        415  400-4344         no        yes     234.4       39.85
#
#       Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 0        197.4         99       16.78       244.7           91         11.01
# 1        195.5        103       16.62       254.4          103         11.45
# 2        121.2        110       10.30       162.6          104          7.32
# 3         61.9         88        5.26       196.9           89          8.86
# 4        148.3        122       12.61       186.9          121          8.41
# 5        220.6        101       18.75       203.9          118          9.18
# 6        348.5        108       29.62       212.6          118          9.57
# 7        103.1         94        8.76       211.8           96          9.53
# 8        351.6         80       29.89       215.8           90          9.71
# 9        222.0        111       18.87       326.4           97         14.69
# 10       228.5         83       19.42       208.8          111          9.40
# 11       163.4        148       13.89       196.0           94          8.82
# 12       104.9         71        8.92       141.1          128          6.35
# 13       247.6         75       21.05       192.3          115          8.65
# 14       307.2         76       26.11       203.0           99          9.14
# 15       317.8         97       27.01       160.6          128          7.23
# 16       280.9         90       23.88        89.3           75          4.02
# 17       218.2        111       18.55       129.6          121          5.83
# 18       212.8         65       18.09       165.7          108          7.46
# 19       159.5         88       13.56       192.8           74          8.68
# 20       239.7         93       20.37       208.8          133          9.40
# 21       169.9        121       14.44       209.6           64          9.43
# 22        72.9         99        6.20       181.8           78          8.18
# 23       137.3        102       11.67       189.6          105          8.53
# 24       245.2         72       20.84       237.0          115         10.67
# 25       277.1        112       23.55       250.7          115         11.28
# 26       191.1        112       16.24       182.7          115          8.22
# 27       155.5        100       13.22       102.1           68          4.59
# 28       258.2         84       21.95       181.5          102          8.17
# 29       215.1        109       18.28       178.7           90          8.04
# ...        ...        ...         ...         ...          ...           ...
# 3303     155.7        125       13.23       247.6           94         11.14
# 3304     198.6        140       16.88       206.5           80          9.29
# 3305     238.8         85       20.30       174.2           86          7.84
# 3306     203.9        131       17.33       229.5           73         10.33
# 3307     234.0        123       19.89       160.7           65          7.23
# 3308     165.7         97       14.08       265.9           72         11.97
# 3309     225.7        102       19.18       255.3           95         11.49
# 3310      92.0        107        7.82       224.8          108         10.12
# 3311     283.3         83       24.08       188.3          124          8.47
# 3312     144.4         93       12.27       262.4          110         11.81
# 3313     143.7         95       12.21       191.4           97          8.61
# 3314     233.7         74       19.86       131.9          120          5.94
# 3315     114.5        106        9.73       178.3           98          8.02
# 3316     219.1         96       18.62       220.3          108          9.91
# 3317     188.5        113       16.02       211.1           94          9.50
# 3318     300.5        118       25.54       192.5          106          8.66
# 3319     209.9        115       17.84       280.9          112         12.64
# 3320     196.4         77       16.69       120.1          133          5.40
# 3321      85.0        110        7.23       210.1          134          9.45
# 3322     265.5        122       22.57       180.5           72          8.12
# 3323     249.3         97       21.19       227.0           56         10.22
# 3324     197.7        105       16.80       193.7           82          8.72
# 3325     116.9         88        9.94       243.3          109         10.95
# 3326     284.8         87       24.21       178.9           92          8.05
# 3327     189.7         68       16.12       221.4          128          9.96
# 3328     215.5        126       18.32       279.1           83         12.56
# 3329     153.4         55       13.04       191.3          123          8.61
# 3330     288.8         58       24.55       191.9           91          8.64
# 3331     159.6         84       13.57       139.2          137          6.26
# 3332     265.9         82       22.60       241.4           77         10.86
#
#       Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0          10.0           3         2.70               1  False.
# 1          13.7           3         3.70               1  False.
# 2          12.2           5         3.29               0  False.
# 3           6.6           7         1.78               2  False.
# 4          10.1           3         2.73               3  False.
# 5           6.3           6         1.70               0  False.
# 6           7.5           7         2.03               3  False.
# 7           7.1           6         1.92               0  False.
# 8           8.7           4         2.35               1  False.
# 9          11.2           5         3.02               0  False.
# 10         12.7           6         3.43               4   True.
# 11          9.1           5         2.46               0  False.
# 12         11.2           2         3.02               1  False.
# 13         12.3           5         3.32               3  False.
# 14         13.1           6         3.54               4  False.
# 15          5.4           9         1.46               4   True.
# 16         13.8           4         3.73               1  False.
# 17          8.1           3         2.19               3  False.
# 18         10.0           5         2.70               1  False.
# 19         13.0           2         3.51               1  False.
# 20         10.6           4         2.86               0  False.
# 21          5.7           6         1.54               5   True.
# 22          9.5          19         2.57               0  False.
# 23          7.7           6         2.08               2  False.
# 24         10.3           2         2.78               0  False.
# 25         15.5           5         4.19               3  False.
# 26          9.5           3         2.57               0  False.
# 27         14.7           4         3.97               3  False.
# 28          6.3           6         1.70               0  False.
# 29         11.1           1         3.00               1  False.
# ...         ...         ...          ...             ...     ...
# 3303       11.5           7         3.11               2  False.
# 3304       13.8           5         3.73               4   True.
# 3305       11.5           7         3.11               2  False.
# 3306        8.1           3         2.19               1  False.
# 3307       17.8           4         4.81               4  False.
# 3308       13.3           6         3.59               1  False.
# 3309       12.0           4         3.24               4  False.
# 3310       13.6          17         3.67               2  False.
# 3311        6.9           5         1.86               2  False.
# 3312       14.2           4         3.83               2  False.
# 3313       10.0           5         2.70               1  False.
# 3314        9.1           4         2.46               1  False.
# 3315        6.5           4         1.76               0  False.
# 3316       12.3           9         3.32               0  False.
# 3317        7.8           8         2.11               1  False.
# 3318       11.6           4         3.13               2  False.
# 3319       15.9           6         4.29               3  False.
# 3320        9.7           4         2.62               4   True.
# 3321       13.2           8         3.56               3  False.
# 3322       11.5           2         3.11               4   True.
# 3323       13.6           3         3.67               5   True.
# 3324       11.6           4         3.13               1  False.
# 3325        9.3           4         2.51               2  False.
# 3326       14.9           7         4.02               1  False.
# 3327       11.8           5         3.19               2  False.
# 3328        9.9           6         2.67               2  False.
# 3329        9.6           4         2.59               3  False.
# 3330       14.1           6         3.81               2  False.
# 3331        5.0          10         1.35               2  False.
# 3332       13.7           4         3.70               0  False.
#
# [3333 rows x 18 columns]

# %%
a = set(desired_cols)
b = set(all_cols_list)
sublist = b - a
sublist
# Out:
# {'Area Code',
#  'Churn?',
#  'CustServ Calls',
#  'Day Charge',
#  'Day Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Eve Mins',
#  "Int'l Plan",
#  'Intl Calls',
#  'Intl Charge',
#  'Intl Mins',
#  'Night Calls',
#  'Night Charge',
#  'Night Mins',
#  'Phone',
#  'State',
#  'VMail Plan'}

# %%
sublist = list(sublist)

# %%
sublist
# Out:
# ['Area Code',
#  'Phone',
#  'Intl Mins',
#  'Intl Charge',
#  'Eve Charge',
#  'Night Calls',
#  'Intl Calls',
#  'Churn?',
#  'Eve Calls',
#  'Day Mins',
#  'Day Charge',
#  'Night Charge',
#  "Int'l Plan",
#  'Eve Mins',
#  'CustServ Calls',
#  'Night Mins',
#  'State',
#  'VMail Plan']
